# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir("/content/drive/MyDrive/project/mul_f_det")

# List files in the directory to verify
# !ls
# Out:
# 'data (2).yaml'   multiple_face_detection.ipynb   test	 train	 val

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 716.2/716.2 kB 7.8 MB/s eta 0:00:00
# ...

# %%
import ultralytics

# %%
from ultralytics import YOLO

# %%
# !yolo  task=detect mode=train model=yolov8s.pt imgsz=640 data='/content/drive/MyDrive/project/mul_f_det/data (2).yaml' epochs=30 batch=16 name=yolov8s
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 135MB/s]
# Ultralytics YOLOv8.1.19 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model='/content/drive/MyDrive/project/mul_f_det/runs/detect/yolov8s/weights/best.pt' conf=0.55 source='/content/drive/MyDrive/project/mul_f_det/test'
# Out:
# Ultralytics YOLOv8.1.19 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/5 /content/drive/MyDrive/project/mul_f_det/test/-1x-1_jpg.rf.469fd3f8e8afde5d3d51946f074f7ea4.jpg: 640x640 10 faces, 16.4ms
# image 2/5 /content/drive/MyDrive/project/mul_f_det/test/1000x-1_jpg.rf.2e37bbf71151ab0b253b1b2190570727.jpg: 640x640 9 faces, 17.0ms
# image 3/5 /content/drive/MyDrive/project/mul_f_det/test/crowd_mask181.jpg: 384x640 12 faces, 104.6ms
# image 4/5 /content/drive/MyDrive/project/mul_f_det/test/family-6398107_1280_jpeg.rf.ff4ca40b6f8eaa7bd19541f591211cc8.jpg: 640x640 4 faces, 17.1ms
# video 5/5 (1/401) /content/drive/MyDrive/project/mul_f_det/test/pexels-pnw-production-8275794 (1080p).mp4: 384x640 2 faces, 21.6ms
# video 5/5 (2/401) /content/drive/MyDrive/project/mul_f_det/test/pexels-pnw-production-8275794 (1080p).mp4: 384x640 2 faces, 11.6ms
# ...
